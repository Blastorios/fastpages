# %% [markdown]
# # Installing K3s, Traefik v2.3 and Cloudflare
# > So You Can Publish/Develop Uninterruptedly
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [devops, k3s, traefik, linux]
# - image: images/k3s_traefik_cloudflare/devops_k3s_post.png
# - hide: true

# %%
#hide_input
# %config Completer.use_jedi = False
